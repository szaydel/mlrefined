# %%
# imports from custom library
import sys
sys.path.append('../../../')
import autograd.numpy as np
from mlrefined_libraries import nonlinear_superlearn_library as nonlib
datapath = '../../../mlrefined_datasets/nonlinear_superlearn_datasets/'
# %matplotlib notebook

# this is needed to compensate for %matplotlib notebook's tendancy to blow up images when plotted inline
from matplotlib import rcParams
rcParams['figure.autolayout'] = True

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 2.  Neural networks

# %% [markdown]
# - **Basic example:** single hidden layer network with *tanh* activation
#
# \begin{equation}
# f_1(x\,,\theta_1) = \text{tanh}\left(w_{1,0} + w_{1,1}x\right), ~~ f_2(x\,,\theta_2) = \text{tanh}\left(w_{2,0} + w_{2,1}x\right), ~~ f_3(x\,,\theta_3) = \text{tanh}\left(w_{3,0} + w_{3,1}x\right), ~~ f_4(x\,,\theta_4) = \text{tanh}\left(w_{4,0} + w_{4,1}x\right), ...
# \end{equation}

# %% [markdown]
# - Each element has *internal parameters*, here $\theta_j = \{w_{0,j},w_{1,j}\}$ internal params for $f_j$

# %%
# import Draw_Bases class for visualizing various basis element types
demo = nonlib.DrawBases.Visualizer()

# plot the first 4 elements of the polynomial basis
demo.show_1d_net(num_layers = 1,activation = 'tanh')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# - **Basic example:** single hidden layer network with *relu* activation
#
# \begin{equation}
# f_1(x\,,\theta_1) = \text{max}\left(0,w_{1,0} + w_{1,1}x\right), ~~ f_2(x\,,\theta_2) = \text{max}\left(0,w_{2,0} + w_{2,1}x\right), ~~ f_3(x\,,\theta_3) = \text{max}\left(0,w_{3,0} + w_{3,1}x\right), ~~ f_4(x\,,\theta_4) = \text{max}\left(0,w_{4,0} + w_{4,1}x\right), ...
# \end{equation}

# %% [markdown]
# - Internal parameters make each function *flexible*

# %%
# import Draw_Bases class for visualizing various basis element types
demo = nonlib.DrawBases.Visualizer()

# plot the first 4 elements of the polynomial basis
demo.show_1d_net(num_layers = 1,activation = 'relu')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ## 2 layer network
# $f_m(x) = \text{max}(0,c_m^{(1)} + \sum_{m_2=1}^{M_2} \text{max}(0,c_{m_2}^{(2)} + \mathbf{x}^T\mathbf{v}_{m_2}^{(2)})v_{{m_2},{m}}^{(1)}$

# %%
# import Draw_Bases class for visualizing various basis element types
demo = nonlib.DrawBases.Visualizer()

# plot the first 4 elements of the polynomial basis
demo.show_1d_net(num_layers = 2,activation = 'tanh')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ## General n layer

# %%
# import Draw_Bases class for visualizing various basis element types
demo = nonlib.DrawBases.Visualizer()

# plot the first 4 elements of the polynomial basis
demo.show_1d_net(num_layers = 10,activation = 'tanh')
# Out:
# <img src="data:image/png;base64,..." width="900">
